# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_stocks = pd.read_csv('./stockPricePaths.csv',header=None)
df_options = pd.read_csv('./optionPricePaths.csv', header=None)
df_errors = pd.read_csv('./hedgingErrorPaths.csv', header=None)

# %%
df_errors.describe()
# Out:
#                0            1            2            3            4    \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.000008     0.000108    -0.000763    -0.000978     0.000680
# std       0.046626     0.063025     0.075690     0.088585     0.096452
# min      -0.372060    -0.357680    -0.442500    -0.509360    -0.488690
# 25%      -0.007365    -0.022643    -0.031527    -0.043185    -0.042450
# 50%       0.017970     0.021435     0.018235     0.020180     0.019590
# 75%       0.027072     0.043513     0.054233     0.065948     0.073060
# max       0.029910     0.059970     0.089740     0.117830     0.148480
#
#                5            6            7            8            9    ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean      0.001781     0.001840     0.001992     0.001494     0.001674  ...
# std       0.109445     0.119225     0.124412     0.132091     0.137330  ...
# ...

# %%
df_errors.drop(df_errors.columns[-1], axis=1, inplace=True)
data = df_errors.to_numpy().flatten()
data
# Out:
# array([ 0.02053, -0.00432,  0.01985, ..., -0.02372, -0.02372, -0.02373])

# %%
plt.figure(figsize=(10, 6))
for index, row in df_stocks.iterrows():
    plt.plot(row.index, row.values)

# Optional: Display a legend if you want to identify each line
plt.legend()

plt.xlabel('Time steps')
plt.ylabel('Stock Prices')
plt.title('Stock Price Paths')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10, 6))
for index, row in df_options.iterrows():
    plt.plot(row.index, row.values)

# Optional: Display a legend if you want to identify each line
plt.legend()

plt.xlabel('Time steps')
plt.ylabel('Option Prices')
plt.title('Option Price Paths')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10, 6))
plt.hist(data, bins=50, density=True, color='skyblue', edgecolor='black')
plt.title('Hedging Error Distribution')
plt.show()
